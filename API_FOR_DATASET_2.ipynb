# %%
import requests
import pandas as pd
# Set display option to show all columns in a dataframe
pd.set_option('display.max_columns', None)
# Set display option to show full content of each cell
pd.set_option('display.max_colwidth', None)

# a handy counter for for-loops
from tqdm.notebook import tqdm

# %%
key = 'O9KQ9V2O0E'

# %%
# create a list of all subjects to query
subjects =["POLITICAL SCIENCE - CIVIL RIGHTS", "WOMEN'S STUDIES", "WOMEN'S HEALTH", "ETHNIC INTERESTS", "MEN'S STUDIES", "LGBTQ+", "LAW - CIVIL LAW", "WOMEN'S INTERESTS", "HISTORY - HISTORY OF THE NEAR EAST" ,"GENERAL INTEREST PERIODICALS - MIDDLE EAST" ,"ASIAN STUDIES" ,"HISTORY - HISTORY OF AFRICA","GENERAL INTEREST PERIODICALS – AFRICA ", "NATIVE AMERICAN STUDIES" ,"HISTORY - HISTORY OF NORTH AND SOUTH AMERICA", "HANDICAPPED - PHYSICALLY IMPAIRED"]

# %%
# create an empty dataframe for collecting metadata
df = pd.DataFrame()

# loop through each subject
for subject in subjects:

    # set the uri to include the subject and the "start" key to allow looping through the results
    uri = f'http://ulrichsweb.serialssolutions.com/api/{key}/search?query=status:A AND serial_type:Journal AND key_feature:RPR AND subject_keyword:{subject}&start='

    # send the first query to get the number of results expected
    r = requests.get(uri + '0')
    numResults = r.json()['totalRecords']

    # let the user know the status
    print(f"{subject} - {r.json()['status']}")

    # set a counter for retrieving results
    i = 0

    # cycle through all results
    while i < numResults:
        r = requests.get(uri + str(i))
        # add the results of each query to the dataframe
        df = pd.concat([df, pd.DataFrame(r.json()['results']['UlrichTitle'])])
        i += 10
# Out:
# POLITICAL SCIENCE - CIVIL RIGHTS - Success
# WOMEN'S STUDIES - Success
# WOMEN'S HEALTH - Success
# ETHNIC INTERESTS - Success
# MEN'S STUDIES - Success
# LGBTQ+ - Success
# LAW - CIVIL LAW - Success
# WOMEN'S INTERESTS - Success
# HISTORY - HISTORY OF THE NEAR EAST - Success
# GENERAL INTEREST PERIODICALS - MIDDLE EAST - Success
# ASIAN STUDIES - Success
# HISTORY - HISTORY OF AFRICA - Success
# GENERAL INTEREST PERIODICALS – AFRICA  - Success
# NATIVE AMERICAN STUDIES - Success
# HISTORY - HISTORY OF NORTH AND SOUTH AMERICA - Success
# HANDICAPPED - PHYSICALLY IMPAIRED - Success

# %%
# using pd.concat (above) can create duplicate indexes. Reset these
df.reset_index(inplace=True, drop=True)

# %%
#some results come back as lists. Convert these columns to a string, joined by "|"
def list_to_string(x):
    if isinstance(x, list):
        try:
            return '|'.join(x)
        except:
            return str(x)
    else:
        return x

df = df.applymap(lambda x: list_to_string(x))

# %%
# some results contain false positive
# (e.g., the subject term "POLITICAL SCIENCE - CIVIL RIGHTS" returns any with "POLITICAL SCIENCE"
# filter out false positives
df = df[df['subject'].isin(subjects)]
print(len(df))
# Out:
# 580

# %%
# other filters
# only English
df = df[df['languages'].str.contains('English')]
print(len(df))
# only Academic / Scholarly
df = df[df['contentTypes'].str.contains('Academic')]
print(len(df))
# Out:
# 546
# 544

# %%
# review the number of results
df.count()
# Out:
# id                    544
# titleId               544
# title                 544
# issn                  438
# lcnumber              260
# coden                  23
# publisher             544
# serialTypes           544
# contentTypes          544
# country               544
# countryCode           544
# status                544
# startYear             333
# deweyNumbers          544
# keyFeatures           544
# otherFeatures         544
# languages             544
# subject               544
# rss                   544
# openAccessUrl          47
# availableOnline       544
# openAccess            544
# refereed              544
# toc                   544
# reviewed              544
# historicTitle         544
# frequency             544
# formats               544
# availableOnlineImg      0
# openAccessImg           0
# refereedImg             0
# tocImg                  0
# reviewedImg             0
# historicTitleImg        0
# price                 544
# description           390
# serialTypesCSV        544
# formatsCSV            544
# languagesCSV          544
# abstractedIndexed     544
# dtype: int64

# %%
# reset index again and review the final list
df.reset_index(inplace=True, drop=True)
df
# Out:
#          id titleId                                         title       issn  \
# 0    733651  786995             Journal of Civil and Human Rights  2378-4245
# 1    733652  786996             Journal of Civil and Human Rights  2378-4253
# 2    679180  737706                               Righting Wrongs  2167-1680
# 3    296673  205929                   China Rights Forum (Online)       None
# 4    347706  243771                     Security and Human Rights  1874-7337
# ..      ...     ...                                           ...        ...
# 539  421580  338218                     American Indian Quarterly  1534-1828
# 540  397364  286180                     American Indian Quarterly       None
# 541   78910   56424  American Indian Culture and Research Journal  0161-6463
# 542  424061  340593  American Indian Culture and Research Journal       None
# 543  396283  284975  American Indian Culture and Research Journal       None
#
#      lcnumber   coden  \
# 0       JC571    None
# 1        None    None
# 2       JC571    None
# 3    JC599.C6    None
# 4    JC599.E9  HMEOAL
# ..        ...     ...
# 539       E75    None
# 540      None    None
# 541       E75    None
# 542      None    None
# 543      None    None
#
#                                                                     publisher  \
# 0                                                University of Illinois Press
# 1                                             Scholarly Publishing Collective
# 2    Webster University * Institute for Human Rights and Humanitarian Studies
# 3                                                       Human Rights in China
# 4                                                             Brill - Nijhoff
# ..                                                                        ...
# 539                                              University of Nebraska Press
# 540                                              University of Nebraska Press
# 541    University of California, Los Angeles * American Indian Studies Center
# 542    University of California, Los Angeles * American Indian Studies Center
# 543    University of California, Los Angeles * American Indian Studies Center
#
#     serialTypes          contentTypes        country countryCode  status  \
# 0       Journal  Academic / Scholarly  United States         USA  Active
# 1       Journal  Academic / Scholarly  United States         USA  Active
# 2       Journal  Academic / Scholarly  United States         USA  Active
# 3       Journal  Academic / Scholarly  United States         USA  Active
# 4       Journal  Academic / Scholarly    Netherlands         NLD  Active
# ..          ...                   ...            ...         ...     ...
# 539     Journal  Academic / Scholarly  United States         USA  Active
# 540     Journal  Academic / Scholarly  United States         USA  Active
# 541     Journal  Academic / Scholarly  United States         USA  Active
# 542     Journal  Academic / Scholarly  United States         USA  Active
# 543     Journal  Academic / Scholarly  United States         USA  Active
#
#     startYear deweyNumbers                 keyFeatures  \
# 0        2015        323.4                     RPR|URL
# 1        None        323.4                 AVO|RPR|URL
# 2        2011          323             AVO|EON|RPR|URL
# 3        1990        323.4      AI|AVO|EON|MLR|RPR|URL
# 4        2008        323.4      AI|CCC|JCR|RPR|TOC|URL
# ..        ...          ...                         ...
# 539      None        970.1              AI|AVO|CCC|RPR
# 540      None        970.1                  AI|CCC|RPR
# 541      1971        970.1  AI|CCC|JCR|MLR|RPR|TOC|URL
# 542      None        970.1              AI|AVO|CCC|RPR
# 543      None        970.1                  AI|CCC|RPR
#
#                      otherFeatures        languages  \
# 0                              ADI          English
# 1                                           English
# 2                         BIA|RPSA          English
# 3         BIA|BIB|BRI|CHI|ILI|REVI  Chinese|English
# 4            ADI|BIA|BRI|REVI|RPSA          English
# ..                             ...              ...
# 539                            BIA          English
# 540                            BIA          English
# 541  ADI|BIA|BRI|ILI|ITA|REVI|RPSA          English
# 542                            BIA          English
# 543                            BIA          English
#
#                               subject rss openAccessUrl  availableOnline  \
# 0    POLITICAL SCIENCE - CIVIL RIGHTS              None            False
# 1    POLITICAL SCIENCE - CIVIL RIGHTS              None             True
# 2    POLITICAL SCIENCE - CIVIL RIGHTS              None             True
# 3    POLITICAL SCIENCE - CIVIL RIGHTS              None             True
# 4    POLITICAL SCIENCE - CIVIL RIGHTS              None            False
# ..                                ...  ..           ...              ...
# 539           NATIVE AMERICAN STUDIES              None             True
# 540           NATIVE AMERICAN STUDIES              None            False
# 541           NATIVE AMERICAN STUDIES              None            False
# 542           NATIVE AMERICAN STUDIES              None             True
# 543           NATIVE AMERICAN STUDIES              None            False
#
#      openAccess  refereed    toc  reviewed  historicTitle      frequency  \
# 0         False      True  False     False          False  Semi-annually
# 1         False      True  False     False          False  Semi-annually
# 2         False      True  False     False          False         Annual
# 3         False      True  False      True          False  Semi-annually
# 4         False      True   True     False          False  Semi-annually
# ..          ...       ...    ...       ...            ...            ...
# 539       False      True  False      True          False      Quarterly
# 540       False      True  False      True          False      Quarterly
# 541       False      True   True      True          False      Quarterly
# 542       False      True  False      True          False      Quarterly
# 543       False      True  False      True          False      Quarterly
#
#        formats availableOnlineImg openAccessImg refereedImg tocImg  \
# 0        Print               None          None        None   None
# 1       Online               None          None        None   None
# 2       Online               None          None        None   None
# 3       Online               None          None        None   None
# 4        Print               None          None        None   None
# ..         ...                ...           ...         ...    ...
# 539     Online               None          None        None   None
# 540  Microform               None          None        None   None
# 541      Print               None          None        None   None
# 542     Online               None          None        None   None
# 543  Microform               None          None        None   None
#
#     reviewedImg historicTitleImg              price  \
# 0          None             None          USD 79.00
# 1          None             None          USD 81.00
# 2          None             None               Free
# 3          None             None               Free
# 4          None             None         USD 323.00
# ..          ...              ...                ...
# 539        None             None         USD 197.00
# 540        None             None  Contact Publisher
# 541        None             None         USD 130.00
# 542        None             None         USD 450.00
# 543        None             None  Contact Publisher
#
#                                                                                                                                                                                                                                      description  \
# 0                                                                                                                                                                                                                                           None
# 1                                                                                                                                                                                                                                           None
# 2                                                                                                    Provides space for students to explore human rights issues, challenge current actions and frameworks, and engage in problem-solving issues.
# 3    Provides space for the voices of Chinese dissidents, scholars, artists, writers and activists promoting democratic reform, labor rights, freedom of expression, and the rights of religious and ethnic minorities and disadvantaged groups.
# 4                                                                                                                                                                Covers cooperation and security in Europe and human rights issues in ONCE area.
# ..                                                                                                                                                                                                                                           ...
# 539                                                                    Brings out work that contributes to the development of American Indian studies as a field and to the sovereignty and continuance of American Indian nations and cultures.
# 540                                                                    Brings out work that contributes to the development of American Indian studies as a field and to the sovereignty and continuance of American Indian nations and cultures.
# 541                                                                                                                                                                Provides an interdisciplinary look at the indigenous people of North America.
# 542                                                                                                                                                                Provides an interdisciplinary look at the indigenous people of North America.
# 543                                                                                                                                                                Provides an interdisciplinary look at the indigenous people of North America.
#
#     serialTypesCSV formatsCSV      languagesCSV  abstractedIndexed
# 0          Journal      Print           English              False
# 1          Journal     Online           English              False
# 2          Journal     Online           English              False
# 3          Journal     Online  Chinese, English               True
# 4          Journal      Print           English               True
# ..             ...        ...               ...                ...
# 539        Journal     Online           English               True
# 540        Journal  Microform           English               True
# 541        Journal      Print           English               True
# 542        Journal     Online           English               True
# 543        Journal  Microform           English               True
#
# [544 rows x 40 columns]

# %%
# Review count of matches for each subject
for subject in subjects:
    # Set the URI to include the subject and the "start" key to allow looping through the results
    uri = f'http://ulrichsweb.serialssolutions.com/api/{key}/search?query=status:A AND serial_type:Journal AND key_feature:RPR AND subject_keyword:{subject}&start=0'

    # Send the query to get all results for the current subject
    r = requests.get(uri)
    numResults = r.json()['totalRecords']

    # Print the count of matches for the current subject
    print(f"{subject}: {numResults} matches")
# Out:
# POLITICAL SCIENCE - CIVIL RIGHTS: 208 matches
# WOMEN'S STUDIES: 75 matches
# WOMEN'S HEALTH: 39 matches
# ETHNIC INTERESTS: 0 matches
# MEN'S STUDIES: 10 matches
# LGBTQ+: 36 matches
# LAW - CIVIL LAW: 1820 matches
# WOMEN'S INTERESTS: 0 matches
# HISTORY - HISTORY OF THE NEAR EAST: 1291 matches
# GENERAL INTEREST PERIODICALS - MIDDLE EAST: 0 matches
# ASIAN STUDIES: 151 matches
# HISTORY - HISTORY OF AFRICA: 1285 matches
# GENERAL INTEREST PERIODICALS – AFRICA : 0 matches
# NATIVE AMERICAN STUDIES: 23 matches
# HISTORY - HISTORY OF NORTH AND SOUTH AMERICA: 0 matches
# HANDICAPPED - PHYSICALLY IMPAIRED: 0 matches
